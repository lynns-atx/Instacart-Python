# %% [markdown]
# # Table of Contents
#
# ## Walk-through while learning
#
# ### 1. Import  libraries
# ### 2. Import data
# ### 3. Take a subset of data
# ### 4. Use if-then function to label products in subset
# ### 5. Use loc() function to label products in subset
#
# ## Questions
#
# ### 1. Create 'price_label' and 'busiest_day' columns
# ### 2. Update the 'busiest_day' column based on clients request
# ### 3. Check the new column for accuracy
# ### 4. Create a 'busiest_period_of_day' column.
# ### 5. Print the frequency for 'busiest_period_of_day'
# ### 6. Check notebook is clean and structure: done!
# ### 7. Export as a pickle file

# %% [markdown]
# ## Walk-through while learning
#
# ### 1. Import  libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 2. Import data

# %%
# Path shortcut

path = r'/Users/lynnsey/Desktop/Bootcamp/Tasks/Immersion/Task 4/07-20-2023 Instacart Basket Analysis'

# %%
# Import data

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ### 3. Take a subset of data

# %%
#Take a subset of data (1,000 rows)

df = ords_prods_merge[:1000000]

# %%
# Check

df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# ### 4. Use if-then function to label products in subset

# %%
# Define a function

def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range'
    else: return 'Not enough data'

# %%
# Apply the function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/kk/6z0tdmb13cd8dwpkbrq630qw0000gn/T/ipykernel_65907/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#Count how many products are in each range

df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# See what the maximum price is in df

df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ### 5. Use loc() function to label products in subset

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## Questions
#
# ### 1. Create 'price_label' and 'busiest_day' columns
#
# #### Create 'price_label' column

# %%
#Use loc() function to label products in entire dataframe with 'High-range product'

ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
#Use loc() function to label products in entire dataframe with 'Mid-range product'

ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
#Use loc() function to label products in entire dataframe with 'Low-range product'

ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Count number of products in each range

ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10131448
# High-range product      412551
# Name: price_range_loc, dtype: int64

# %%
#Checking to make sure column was created

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc
# ...

# %% [markdown]
# #### Create 'busiest_day' column

# %%
# Showing how many items are ordered each day of the week

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Create a new column with busiest days

result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# Checking the result

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create a new column with the busy-ness level in the dataframe

ords_prods_merge['busiest_day'] = result

# %%
# Count the busy-ness of each day

ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
# Showing dataframe to make sure both columns were successfully added on

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ### 2. Update the 'busiest_day' column based on clients request

# %% [markdown]
# #### Remove 'busiest_day' column

# %%
# Remove current 'busiest_day' column

ords_prods_merge = ords_prods_merge.drop(columns = ['busiest_day'])

# %%
# Check if removed

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc
# ...

# %% [markdown]
# #### Create a new column with days labeled the new way

# %%
# Create a new column with busiest days

result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest days")
  elif value == 1:
    result.append("Busiest days")
  elif value == 3:
    result.append("Slowest days")
  elif value == 4:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
# Checking the result

result
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %% [markdown]
# #### Add the column into the dataframe

# %%
# Add the column into the dataframe

ords_prods_merge['Busiest_days'] = result

# %% [markdown]
# #### Check to make sure the dataframe has new column

# %%
# Check to see if it all looks correct

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ### 3. Check the new column for accuracy

# %%
# Count the busiest days

ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: Busiest_days, dtype: int64

# %%
# Count the days of the week to compare

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# #### Using the day of the week frequency, I added day 0+1, which equaled the frequency of the 'Busiest days' above.  I did the same with the days 3+4, which equaled the frequency of the 'Slowest days' above.  Since there were no missing values, I determined that the 'Regularly busy' days equaled the rest of the days of the week.

# %% [markdown]
# ### 4. Create a 'busiest_period_of_day' column.

# %% [markdown]
# #### Check order frequency by hour

# %%
#Frequency of orders by hour

ords_prods_merge['time_ordered'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: time_ordered, dtype: int64

# %% [markdown]
# #### Create a  new column with groupings

# %%
# Create a new column with 'busiest_period_of_day'

result_1 = []

for value in ords_prods_merge['time_ordered']:
  if value in [9, 10, 11, 12, 13, 14, 16]:
    result_1.append("Most orders")
  elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
    result_1.append('Average orders')
  else:
    result_1.append('Fewest orders')

# %%
result_1
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %% [markdown]
# #### Add column into the dataframe

# %%
# Add the column into the dataframe

ords_prods_merge['busiest_period_of_day'] = result_1

# %% [markdown]
# #### Check to see if successful

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_ordered  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# ### 5. Print the frequency for 'busiest_period_of_day'

# %%
# Print frequency for 'busiest_period_of_day'

ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       18455927
# Average orders     9997651
# Fewest orders      3951281
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ### 6. Check notebook is clean and structure: done!

# %% [markdown]
# ### 7. Export as a pickle file

# %%
# Export as a pickle file

ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined_new_columns.pkl'))
